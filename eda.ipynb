# %% [markdown]
# <h2>US Presidents</h2>
#
# <p> Data obtained from Kaggle:
# https://www.kaggle.com/datasets/georgescutelnicu/us-presidents

# %%
import pandas as pd

# %%
df = pd.read_csv('presidents.csv').set_index('No.')
df.shape
# Out:
# (46, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46 entries, 1 to 46
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               46 non-null     object
#  1   Birthplace         46 non-null     object
#  2   Birthday           46 non-null     object
#  3   Life               46 non-null     object
#  4   Height             46 non-null     float64
#  5   Children           46 non-null     int64
#  6   Religion           46 non-null     object
#  7   Higher Education   46 non-null     object
#  8   Occupation         46 non-null     object
#  9   Military Service   46 non-null     object
#  10  Term               46 non-null     object
#  11  Party              46 non-null     object
#  12  Vice President     46 non-null     object
#  13  Previous Office    46 non-null     object
#  14  Economy            46 non-null     object
#  15  Foreign Affairs    46 non-null     object
#  16  Military Activity  46 non-null     object
#  17  Other Events       46 non-null     object
#  18  Legacy             46 non-null     object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 7.2+ KB

# %%
df.head(6)
# Out:
#                   Name            Birthplace Birthday       Life  Height  \
# No.
# 1    George Washington      Pope's Creek, VA   22-Feb  1732-1799    1.88
# 2           John Adams         Braintree, MA   30-Oct  1735-1826    1.70
# 3     Thomas Jefferson  Goochland County, VA   13-Apr  1743-1826    1.89
# 4        James Madison       Port Conway, VA   16-Mar  1751-1836    1.63
# 5         James Monroe       Monroe Hall, VA   28-Apr  1758-1831    1.83
# 6    John Quincy Adams         Braintree, MA   11-Jul  1767-1848    1.70
#
#      Children                Religion             Higher Education  \
# No.
# 1           0            Episcopalian                         None
# 2           5               Unitarian                      Harvard
# 3           6  unaffiliated Christian  College of William and Mary
# 4           0            Episcopalian                    Princeton
# 5           2            Episcopalian  College of William and Mary
# 6           4               Unitarian                      Harvard
#
#                      Occupation  \
# No.
# 1     Plantation Owner, Soldier
# 2                Lawyer, Farmer
# 3    Inventor,Lawyer, Architect
# 4      Plantation Owner, Lawyer
# 5      Plantation Owner, Lawyer
# 6              Lawyer, Diplomat
#
#                                       Military Service       Term  \
# No.
# 1    Commander-in-Chief of the  Continental Army in...  1789-1797
# 2                                                 none  1797-1801
# 3    Colonel of Virginia militia (without real mili...  1801-1809
# 4    Colonel of Virginia militia (without real mili...  1809-1817
# 5                        Major of the Continental Army  1817-1825
# 6                                                 none  1825-1829
#
#                      Party                  Vice President  \
# No.
# 1         None, Federalist                      John Adams
# 2               Federalist                Thomas Jefferson
# 3    Democratic-Republican      Aaron Burr, George Clinton
# 4    Democratic-Republican  George Clinton, Elbridge Gerry
# 5    Democratic-Republican                 Daniel Tompkins
# 6    Democratic-Republican                    John Calhoun
#
#                Previous Office  \
# No.
# 1           Commander-in-Chief
# 2    1st Vice President of USA
# 3    2nd Vice President of USA
# 4           Secretary of State
# 5             Secretary of War
# 6           Secretary of State
#
#                                                Economy  \
# No.
# 1    [' Hamilton established BUS', '1792 Coinage Ac...
# 2    ['1798 Progressive land value tax of up to 1% ...
# 3    ['1807 Embargo Act forbidding foreign trade in...
# 4    [' The first U.S. protective tariff was impose...
# 5    ['1819 Panic of 1819 (too much land speculatio...
# 6    [' "Internal improvements" program (roads, por...
#
#                                        Foreign Affairs  \
# No.
# 1    ['1793 Neutrality in the France-Britain confli...
# 2    ['1797 the XYZ Affair: a bribe of French agent...
# 3    ['1805 Peace Treaty with Tripoli. Piracy stopp...
# 4    ['1814 The Treaty of Ghent ends the War of 1812']
# 5    ['1823 Monroe Doctrine', '1818 49th parallel s...
# 6    ['Unsuccessful attempt to purchase Texas from ...
#
#                                      Military Activity  \
# No.
# 1                           ['1794 Whiskey Rebellion']
# 2    ['1798–1800 The Quasi war. Undeclared naval wa...
# 3    ['1801-05 Naval operation against Tripoli and ...
# 4    ['1811 Tippecanoe battle (Harrison vs. Chief T...
# 5    ['1817 1st Seminole war against Seminole India...
# 6                                             ['None']
#
#                                           Other Events  \
# No.
# 1    ['1791 Bill of Rights', '1792 Post Office foun...
# 2    ['1798 Alien & Sedition Act to silence critics...
# 3    ['1803 The Louisiana purchase', '1804 12th Ame...
# 4    ['1811 Cumberland Road construction starts (fi...
# 5    ['1819 Florida ceded to US', "1820 Missouri Co...
# 6    [' Accused for "corrupt bargain" to obtain Cla...
#
#                                                 Legacy
# No.
# 1    He is universally regarded as one of the great...
# 2    One of the most experienced men ever to become...
# 3    Probably  the most intelligent man ever to occ...
# 4    His leadership in the War of 1812 was particul...
# 5    His presidency contributed to national defense...
# 6    He had been an excellent Secretary of State, m...

# %% [markdown]
# <h3>Data Wrangling</h3>

# %% [markdown]
# - extract state from `birthplace` <br>
# - seperate `life` details to `birth_year` + `death_year` columns <br>
# - convert `height` from meters to feet <br>
# - create term column (one vs two terms) <br>

# %%
#updating data type before beginning transformations
df = df.astype({
    'Name': 'string',
    'Birthplace': 'string',
    'Life': 'string',
    'Children': 'int',
    'Religion': 'string',
    'Higher Education': 'string',
    'Occupation': 'string',
    'Term': 'string',
    'Party': 'string',
    'Legacy': 'string'
})

# %% [markdown]
# <p> Splitting a few records into individual columns.

# %%
df[['city_of_birth', 'state_of_birth']] = df['Birthplace'].str.split(",", n=1, expand=True)

# %%
df[['dob_day', 'dob_month']] = df['Birthday'].str.split('-', n=1, expand=True)

# %%
df[['year_of_birth', 'year_of_death']] = df['Life'].str.split('-', n=1, expand=True)

# %%
#now convert months into numberical month value (so I can merge to make DOB)
months = {
    'Feb': 2,
 'Oct': 10,
 'Apr': 4,
 'Mar': 3,
 'Jul': 7,
 'Dec': 12,
 'Nov': 11,
 'Jan': 1,
 'Aug': 8,
 'Sep': 9,
 'May': 5,
 'Jun': 6
}

# %%
#temp variable for the month
df['num_month'] = df.dob_month.map(months)

# %%
#converting height in meters to feet and inches
def height(meters):
    feet = int(meters / 0.3048)
    inches = int(meters / 0.3048 % 1 * 12)
    new_height = float(f'{feet}.{inches}') #combining feet + inches into one variable
    return new_height

df['new_height'] = df["Height"].apply(height)

# %%
df.columns
# Out:
# Index(['Name', 'Birthplace', 'Birthday', 'Life', 'Height', 'Children',
#        'Religion', 'Higher Education', 'Occupation', 'Military Service',
#        'Term', 'Party', 'Vice President', 'Previous Office', 'Economy',
#        'Foreign Affairs', 'Military Activity', 'Other Events', 'Legacy',
#        'city_of_birth', 'state_of_birth', 'dob_day', 'dob_month',
#        'year_of_birth', 'year_of_death', 'num_month', 'new_height'],
#       dtype='object')

# %%
df.head(5)
# Out:
#                   Name            Birthplace Birthday       Life  Height  \
# No.
# 1    George Washington      Pope's Creek, VA   22-Feb  1732-1799    1.88
# 2           John Adams         Braintree, MA   30-Oct  1735-1826    1.70
# 3     Thomas Jefferson  Goochland County, VA   13-Apr  1743-1826    1.89
# 4        James Madison       Port Conway, VA   16-Mar  1751-1836    1.63
# 5         James Monroe       Monroe Hall, VA   28-Apr  1758-1831    1.83
#
#      Children                Religion             Higher Education  \
# No.
# 1           0            Episcopalian                         None
# 2           5               Unitarian                      Harvard
# 3           6  unaffiliated Christian  College of William and Mary
# 4           0            Episcopalian                    Princeton
# 5           2            Episcopalian  College of William and Mary
#
#                      Occupation  \
# No.
# 1     Plantation Owner, Soldier
# 2                Lawyer, Farmer
# 3    Inventor,Lawyer, Architect
# 4      Plantation Owner, Lawyer
# 5      Plantation Owner, Lawyer
#
#                                       Military Service  ...  \
# No.                                                     ...
# 1    Commander-in-Chief of the  Continental Army in...  ...
# 2                                                 none  ...
# 3    Colonel of Virginia militia (without real mili...  ...
# 4    Colonel of Virginia militia (without real mili...  ...
# 5                        Major of the Continental Army  ...
#
#                                           Other Events  \
# No.
# 1    ['1791 Bill of Rights', '1792 Post Office foun...
# 2    ['1798 Alien & Sedition Act to silence critics...
# 3    ['1803 The Louisiana purchase', '1804 12th Ame...
# 4    ['1811 Cumberland Road construction starts (fi...
# 5    ['1819 Florida ceded to US', "1820 Missouri Co...
#
#                                                 Legacy     city_of_birth  \
# No.
# 1    He is universally regarded as one of the great...      Pope's Creek
# 2    One of the most experienced men ever to become...         Braintree
# 3    Probably  the most intelligent man ever to occ...  Goochland County
# 4    His leadership in the War of 1812 was particul...       Port Conway
# 5    His presidency contributed to national defense...       Monroe Hall
#
#     state_of_birth dob_day dob_month year_of_birth year_of_death num_month  \
# No.
# 1               VA      22       Feb          1732          1799         2
# 2               MA      30       Oct          1735          1826        10
# 3               VA      13       Apr          1743          1826         4
# 4               VA      16       Mar          1751          1836         3
# 5               VA      28       Apr          1758          1831         4
#
#     new_height
# No.
# 1          6.2
# 2          5.6
# 3          6.2
# 4          5.4
# 5          6.0
#
# [5 rows x 27 columns]
